# %%
import cv2

# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import gzip,pickle,sys
import numpy as np
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
#from keras import backend as K
import PIL
import numpy as np
import random
import matplotlib.pyplot as plt
from random import randint
import os
import shutil
import pandas as pd
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
import itertools

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1146123532083109919,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3048682292
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12952279457783201491
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5"]

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
batch_size = 32
img_height = 100
img_width = 100
mg_channels = 1
data_dir = './dataset/train'
labels = os.listdir(data_dir)

# %%
print(labels)
print(len(labels))
# Out:
# ['Car', 'Truck']
# 2

# %%
#splitting the dataset

# import splitfolders
# splitfolders.ratio(data_dir, output="Data Split", seed=1337, ratio=(0.7, 0.2, 0.1))

# %%
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                img_arr = cv2.cvtColor(img_arr, cv2.COLOR_RGB2GRAY)
                resized_arr = cv2.resize(img_arr, (img_height, img_width)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

# %%
train = get_data('./dataset/train')

# %%
val = get_data('./dataset/valid')

# %%
# test = get_data('./Data Split/test')

# %%
print(train.shape)
# print(test.shape)
print(val.shape)
# Out:
# (5117, 2)
# (5051, 2)

# %%
x_train = []
y_train = []
x_val = []
y_val = []
# x_test = []
# y_test = []
for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# for feature, label in test:
#     x_test.append(feature)
#     y_test.append(label)


# Normalize the data
x_train = np.array(x_train)
x_val = np.array(x_val)
# x_test = np.array(x_test)

x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
# x_test = x_test.astype('float32')

x_train /= 255
x_val /= 255
# x_test /= 255

x_train.reshape(-1, img_height, img_width, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_height, img_width, 1)
y_val = np.array(y_val)

# x_test.reshape(-1, img_height, img_width, 1)
# y_test = np.array(y_test)

plt.imshow(x_val[9])
print("Image label: "+str(y_val[9]))
# Out:
# Image label: 0

# %%
x_val, x_test, y_val, y_test= train_test_split(x_val, y_val, test_size=0.5)

# %%
print('x_train shape:', x_train.shape)
print('x_val shape:', x_val.shape)
print('x_test shape:', x_test.shape)

print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (5117, 100, 100)
# x_val shape: (2525, 100, 100)
# x_test shape: (2526, 100, 100)
# 5117 train samples
# 2525 validation samples
# 2526 test samples

# %%
import seaborn as sns

plt.style.use("ggplot")
plt.figure(figsize=(12,5))
plt.title("Datase Samples Distribution")
sns.countplot(x = y_train)
plt.xlabel('Labels')
plt.ylabel('Images')
plt.show()

# %%
# a = np.arange(0,1000,1)
# #taking thousand random samples
# b = np.random.choice(Y_train, size=1000, replace=False)

# #print(a, b)

# for x, y in zip(a, b):
#     rgb = np.random.rand(3,)
#     plt.scatter(x, y, c=[rgb])
# plt.title("Dataset III Samples Distribution")
# plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
earlystopper = EarlyStopping(patience=10, verbose=1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
class MetricsCheckpoint(Callback):
    """Callback that saves metrics after each epoch"""
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

# %%
datagen = ImageDataGenerator(
        featurewise_center=True,  # set input mean to 0 over the dataset
        samplewise_center=True,  # set each sample mean to 0
        featurewise_std_normalization=True,  # divide inputs by std of the dataset
        samplewise_std_normalization=True,  # divide each input by its std
        zca_whitening=True,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
# Out:
# C:\Users\rafir\anaconda3\envs\Rafi\lib\site-packages\keras_preprocessing\image\image_data_generator.py:342: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
x_train = x_train.reshape(-1, img_height, img_width, 1)
x_val = x_val.reshape(-1, img_height, img_width, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)

# %%
datagen.fit(x_train)

# %%
num_classes = len(labels)
img_channels = 1

model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), padding='same', 
                 activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros',
                 input_shape=(img_height, img_width, 1)))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), padding='same',  activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(Conv2D(256, (3, 3),padding='same',  activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

#save model to disk
model_json=model.to_json()
with open ("model.json","w") as json_file:
    json_file.write(model_json)
    print("Model Saved")
# Out:
# Model Saved

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 64)      640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4718720
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,863,234
# Trainable params: 5,863,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
#using Sparse Categorical Crossentropy
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#using augmentation

epochs = 100

history=model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_val, y_val), callbacks = [MetricsCheckpoint('logs'), earlystopper,learning_rate_reduction])
print(history)
model.save_weights("modelWeight.h5")
score = model.evaluate(x_test, y_test, verbose=0)

print(' Training Complete ')
print('Test loss:', score[0])
print('Test accuracy:', score[1]*100)
# Out:
# Epoch 1/100
#   6/160 [>.............................] - ETA: 22s - loss: 0.8677 - accuracy: 0.4508WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0375s vs `on_train_batch_end` time: 0.0885s). Check your callbacks.
# 160/160 [==============================] - 33s 177ms/step - loss: 0.7085 - accuracy: 0.5572 - val_loss: 0.6810 - val_accuracy: 0.5782
# Epoch 2/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6846 - accuracy: 0.5721 - val_loss: 0.6815 - val_accuracy: 0.5782
# Epoch 3/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6835 - accuracy: 0.5754 - val_loss: 0.6809 - val_accuracy: 0.5782
# Epoch 4/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6814 - accuracy: 0.5791 - val_loss: 0.6811 - val_accuracy: 0.5782
# Epoch 5/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6799 - accuracy: 0.5845 - val_loss: 0.6812 - val_accuracy: 0.5782
# Epoch 6/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6809 - accuracy: 0.5802 - val_loss: 0.6809 - val_accuracy: 0.5782
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6776 - accuracy: 0.5897 - val_loss: 0.6812 - val_accuracy: 0.5782
# Epoch 8/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6765 - accuracy: 0.5932 - val_loss: 0.6782 - val_accuracy: 0.5782
# Epoch 9/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6771 - accuracy: 0.5777 - val_loss: 0.6810 - val_accuracy: 0.5782
# Epoch 10/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6814 - accuracy: 0.5771 - val_loss: 0.6809 - val_accuracy: 0.5782
# Epoch 11/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6854 - accuracy: 0.5637 - val_loss: 0.6809 - val_accuracy: 0.5782
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/100
# 160/160 [==============================] - 25s 158ms/step - loss: 0.6819 - accuracy: 0.5762 - val_loss: 0.6809 - val_accuracy: 0.5782
# Epoch 13/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6822 - accuracy: 0.5725 - val_loss: 0.6681 - val_accuracy: 0.5933
# Epoch 14/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6672 - accuracy: 0.6019 - val_loss: 0.6678 - val_accuracy: 0.5861
# Epoch 15/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6626 - accuracy: 0.6042 - val_loss: 0.6265 - val_accuracy: 0.6661
# Epoch 16/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.6157 - accuracy: 0.6624 - val_loss: 0.5687 - val_accuracy: 0.7248
# Epoch 17/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.5753 - accuracy: 0.7099 - val_loss: 0.5656 - val_accuracy: 0.7034
# Epoch 18/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.5431 - accuracy: 0.7210 - val_loss: 0.5386 - val_accuracy: 0.7271
# Epoch 19/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.5141 - accuracy: 0.7565 - val_loss: 0.5010 - val_accuracy: 0.7655
# Epoch 20/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.5102 - accuracy: 0.7478 - val_loss: 0.5024 - val_accuracy: 0.7608
# Epoch 21/100
# 160/160 [==============================] - 25s 160ms/step - loss: 0.4854 - accuracy: 0.7757 - val_loss: 0.4627 - val_accuracy: 0.7834
# Epoch 22/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.4279 - accuracy: 0.8015 - val_loss: 0.4477 - val_accuracy: 0.8044
# Epoch 23/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.4390 - accuracy: 0.7967 - val_loss: 0.4246 - val_accuracy: 0.8016
# Epoch 24/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.4058 - accuracy: 0.8196 - val_loss: 0.3772 - val_accuracy: 0.8293
# Epoch 25/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.4114 - accuracy: 0.8205 - val_loss: 0.4156 - val_accuracy: 0.8123
# Epoch 26/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.3626 - accuracy: 0.8394 - val_loss: 0.3570 - val_accuracy: 0.8487
# Epoch 27/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.3603 - accuracy: 0.8379 - val_loss: 0.3395 - val_accuracy: 0.8539
# Epoch 28/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.3425 - accuracy: 0.8522 - val_loss: 0.3267 - val_accuracy: 0.8610
# Epoch 29/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.3232 - accuracy: 0.8674 - val_loss: 0.3644 - val_accuracy: 0.8424
# Epoch 30/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.3045 - accuracy: 0.8670 - val_loss: 0.3207 - val_accuracy: 0.8661
# Epoch 31/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2947 - accuracy: 0.8672 - val_loss: 0.2997 - val_accuracy: 0.8756
# Epoch 32/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2957 - accuracy: 0.8766 - val_loss: 0.3110 - val_accuracy: 0.8646
# Epoch 33/100
# 160/160 [==============================] - 25s 159ms/step - loss: 0.2776 - accuracy: 0.8817 - val_loss: 0.2807 - val_accuracy: 0.8848
# Epoch 34/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2560 - accuracy: 0.8953 - val_loss: 0.3293 - val_accuracy: 0.8602
# Epoch 35/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2545 - accuracy: 0.8953 - val_loss: 0.2797 - val_accuracy: 0.8796
# Epoch 36/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2449 - accuracy: 0.8964 - val_loss: 0.2681 - val_accuracy: 0.8899
# Epoch 37/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2528 - accuracy: 0.8966 - val_loss: 0.2765 - val_accuracy: 0.8832
# Epoch 38/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2226 - accuracy: 0.9042 - val_loss: 0.2446 - val_accuracy: 0.9026
# Epoch 39/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2273 - accuracy: 0.9018 - val_loss: 0.2611 - val_accuracy: 0.8911
# Epoch 40/100
# 160/160 [==============================] - 25s 160ms/step - loss: 0.2356 - accuracy: 0.9034 - val_loss: 0.2494 - val_accuracy: 0.8978
# Epoch 41/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2175 - accuracy: 0.9100 - val_loss: 0.2415 - val_accuracy: 0.9030
# Epoch 42/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2088 - accuracy: 0.9204 - val_loss: 0.2439 - val_accuracy: 0.9034
# Epoch 43/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2062 - accuracy: 0.9167 - val_loss: 0.2657 - val_accuracy: 0.8970
# Epoch 44/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1958 - accuracy: 0.9227 - val_loss: 0.2617 - val_accuracy: 0.8954
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 45/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1751 - accuracy: 0.9322 - val_loss: 0.2355 - val_accuracy: 0.9081
# Epoch 46/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1711 - accuracy: 0.9297 - val_loss: 0.2335 - val_accuracy: 0.9077
# Epoch 47/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1432 - accuracy: 0.9427 - val_loss: 0.2194 - val_accuracy: 0.9121
# Epoch 48/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1674 - accuracy: 0.9325 - val_loss: 0.2224 - val_accuracy: 0.9121
# Epoch 49/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1563 - accuracy: 0.9375 - val_loss: 0.2194 - val_accuracy: 0.9121
# Epoch 50/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1487 - accuracy: 0.9424 - val_loss: 0.2205 - val_accuracy: 0.9141
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 51/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1479 - accuracy: 0.9442 - val_loss: 0.2462 - val_accuracy: 0.9053
# Epoch 52/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1458 - accuracy: 0.9451 - val_loss: 0.2157 - val_accuracy: 0.9152
# Epoch 53/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1329 - accuracy: 0.9487 - val_loss: 0.2272 - val_accuracy: 0.9105
# Epoch 54/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1219 - accuracy: 0.9564 - val_loss: 0.2174 - val_accuracy: 0.9145
# Epoch 55/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1406 - accuracy: 0.9422 - val_loss: 0.2086 - val_accuracy: 0.9188
# Epoch 56/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1333 - accuracy: 0.9485 - val_loss: 0.2192 - val_accuracy: 0.9176
# Epoch 57/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1176 - accuracy: 0.9514 - val_loss: 0.2287 - val_accuracy: 0.9145
# Epoch 58/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1251 - accuracy: 0.9509 - val_loss: 0.2079 - val_accuracy: 0.9212
# Epoch 59/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1250 - accuracy: 0.9548 - val_loss: 0.2170 - val_accuracy: 0.9184
# Epoch 60/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1346 - accuracy: 0.9403 - val_loss: 0.2100 - val_accuracy: 0.9244
# Epoch 61/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1313 - accuracy: 0.9515 - val_loss: 0.2275 - val_accuracy: 0.9129
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 62/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1147 - accuracy: 0.9540 - val_loss: 0.2077 - val_accuracy: 0.9212
# Epoch 63/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1197 - accuracy: 0.9524 - val_loss: 0.2113 - val_accuracy: 0.9212
# Epoch 64/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1194 - accuracy: 0.9524 - val_loss: 0.2117 - val_accuracy: 0.9216
# Epoch 65/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1224 - accuracy: 0.9546 - val_loss: 0.2110 - val_accuracy: 0.9208
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 66/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1181 - accuracy: 0.9506 - val_loss: 0.2249 - val_accuracy: 0.9184
# Epoch 67/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1147 - accuracy: 0.9558 - val_loss: 0.2140 - val_accuracy: 0.9192
# Epoch 68/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1343 - accuracy: 0.9495 - val_loss: 0.2139 - val_accuracy: 0.9200
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 69/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1117 - accuracy: 0.9590 - val_loss: 0.2157 - val_accuracy: 0.9188
# Epoch 70/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1172 - accuracy: 0.9526 - val_loss: 0.2136 - val_accuracy: 0.9188
# Epoch 71/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1167 - accuracy: 0.9600 - val_loss: 0.2123 - val_accuracy: 0.9188
# Epoch 72/100
# 160/160 [==============================] - 26s 160ms/step - loss: 0.1226 - accuracy: 0.9493 - val_loss: 0.2175 - val_accuracy: 0.9196
# Epoch 00072: early stopping
# <tensorflow.python.keras.callbacks.History object at 0x000002073F78EDC0>
#  Training Complete
# Test loss: 0.1929415911436081
# Test accuracy: 93.03246140480042

# %%
range(earlystopper.stopped_epoch)
# Out:
# range(0, 71)

# %%
def plotKerasLearningCurve():
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy', allow_pickle=True)[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='Validation Accuracy' if 'val' in k else 'Training Accuracy')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('Number of epochs')
    plt.ylabel('Accuracy')
    plt.title('Training Accuracy vs Validation Accuracy')

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred,axis=1) 
y_true = np.argmax(y_test,axis=0)
plotKerasLearningCurve()
plt.show()

# %%
train_loss=history.history['loss']
val_loss=history.history['val_loss']
train_acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

xc=range(earlystopper.stopped_epoch+1)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.grid(True)
plt.legend(['Training Loss','Validation Lossl'])
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

# %%
model_json=model.to_json()
with open ("model.json","w") as json_file:
    json_file.write(model_json)
    print("Model Saved")
# Out:
# Model Saved

# %%
#load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = keras.models.model_from_json(loaded_model_json)
#load weights into new model
loaded_model.load_weights("modelWeight.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
score = loaded_model.evaluate(x_test, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 93.03%

# %%
y_pred = loaded_model.predict(x_test)
y_pred_classes = np.argmax(y_pred,axis=1) 
y_true = y_test

# %%
confusion_mtx = confusion_matrix(y_true, y_pred_classes) 
print('Confusion Matrix\n')
print(confusion_mtx)
# Out:
# Confusion Matrix
#
# [[1410   52]
#  [ 124  940]]

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_true, y_pred_classes, target_names=labels))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#          Car       0.92      0.96      0.94      1462
#        Truck       0.95      0.88      0.91      1064
#
#     accuracy                           0.93      2526
#    macro avg       0.93      0.92      0.93      2526
# weighted avg       0.93      0.93      0.93      2526

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (25,15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
classes=labels
len(classes)
plot_confusion_matrix(confusion_mtx, classes)
plt.show()
